# %%
import pandas as pd
import pprint
# !pip install elasticsearch
from elasticsearch import Elasticsearch, helpers
import csv

es = Elasticsearch('')

# %%
def delete_index(index):
    if es.indices.exists(index=index):
        return es.indices.delete(index=index)
    else:
        return "index not exist"

# %%
def search(es, index,  keyword = None):
    body = {
        "query":{
            "multi_match":{
                "query": keyword,
                "fields" : ['영문명', '한글명']
                }
            }
        }
    res = es.search(index=index, body=body)
    
    return res

# %%
with open(r"C:\Users\belab\Desktop\jun\jupyter\ElasticSearch\clinicWord.csv") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index="test_jun", doc_type="doc")
    f.close()
# Out:
# C:\Users\belab\anaconda3\lib\site-packages\elasticsearch\connection\base.py:209: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)

# %%
search(es, 'test_jun', '가슴')
# Out:
# <ipython-input-12-9aa5d6c99bf1>:10: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in 8.0.0. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   res = es.search(index=index, body=body)
# {'took': 1623,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1572, 'relation': 'eq'},
#   'max_score': 8.933235,
#   'hits': [{'_index': 'test_jun',
#     '_type': 'doc',
#     '_id': '5_rGWXwBwCLgtTq-NZeA',
#     '_score': 8.933235,
#     '_source': {'용어코드': 'H00207827',
#      '개념코드': 'H00207813',
#      '영문명': 'Breast',
#      '한글명': '가슴',
#      'UMLS': 'C0006141',
#      '버전': '[5.0]',
#      'KCD': '',
#      'ICD9CM': '',
#      'LOINC': '',
#      'EDI': '',
#      'CCC': '',
#      'ICNP': '10003650',
#      'CDT': ''}},
#    {'_index': 'test_jun',
#     '_type': 'doc',
# ...
