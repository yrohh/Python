# %%
import csv
f = open('age2.csv')
data = csv.reader(f)

m = []
f = []

name = input('입력 : ')

for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(-int(i))
        for j in row[106:] :
            f.append(int(j))

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()
# Out:
# 입력 : 인창동

# %%
import csv
f = open('age2.csv')
data = csv.reader(f)

m = []
f = []

name = input('입력 : ')

for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(-int(i))
        for j in row[106:] :
            f.append(int(j))

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()
# Out:
# 입력 : 제주특별자치도
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-977a52aca69a> in <module>
#      11     if name in row[0] :
#      12         for i in row[3:104] :
# ---> 13             m.append(-int(i))
#      14         for j in row[106:] :
#      15             f.append(int(j))
#
# ValueError: invalid literal for int() with base 10: '1,931'

# %%
import csv
f = open('age2.csv')
data = csv.reader(f)

m = []
f = []

name = input('입력 : ')

for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(-int(i.replace(',','')))
        for j in row[106:] :
            f.append(int(j.replace(',','')))

print(len(m), len(f))
# Out:
# 입력 : 제주특별자치도
# 4646 4646

# %% [markdown]
# ### break 키워드 입력해줌으로써, '제주특별자치도'를 포함하는 행 중 첫 번째 행의 값들만 가져옴.

# %%
import csv
f = open('age2.csv')
data = csv.reader(f)

m = []
f = []

name = input('입력 : ')

for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(-int(i.replace(',','')))
        for j in row[106:] :
            f.append(int(j.replace(',','')))
        break

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()
# Out:
# 입력 : 제주특별자치도

# %%
import matplotlib.pyplot as plt
plt.pie([10,30])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.pie([10,30])
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
label=['빨','주','노','초']
plt.axis('equal')
plt.pie([1,3,5,7], labels=label, counterclock=False, startangle=90)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5), dpi=300)
label=['빨','주','노','초']
plt.axis('equal')
plt.pie([1,3,5,7], labels=label, counterclock=False, startangle=90, autopct='%.1f%%')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5), dpi=300)
label=['빨','주','노','초']
color=['orangered','bisque','lemonchiffon','springgreen']
plt.axis('equal')
plt.pie([1,3,5,7], labels=label, counterclock=False, startangle=90, autopct='%.1f%%', colors=color, explode=(0.1,0,0,0))
plt.legend()
plt.show()

# %%
import csv
f = open('age2.csv')
data = csv.reader(f)


name = input('입력 : ')

for row in data :
    if name in row[0] :
        m = int(row[1].replace(',',''))
        f = int(row[105].replace(','.'')]
        break

import matplotlib.pyplot as plt
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.title(name + ' 지역의 남녀 성별 인구 비율')
label=['남','여']
color=['blue','red']
plt.pie([m,f], labels=label, colors=color, autopct='%.1f%%', startangle=)
plt.axis('equal')
plt.legend()
plt.show()
